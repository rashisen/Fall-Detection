# %%
from models import *
from seq_exp import SeqExp


if __name__ == "__main__":
        '''
        These are the training setting. 
        '''
        dset = 'UR-Filled'
        img_width, img_height, win_len, epochs = 64,64, 8,50 #win len is set to 8 for paper
        stride = 1
       
        model, model_name, model_type = DSTCAE_C3D(img_width, img_height, win_len)
        

        print('model loaded')
        print(model.summary())

        exp_3D = SeqExp(model = model, model_name = model_name, epochs = epochs, \
                win_len = win_len, dset = dset, img_width = img_width, img_height = img_height)
        exp_3D.set_train_data()

        print(exp_3D.train_data.shape)
        print('data loaded')
        exp_3D.train()
# Out:
# Using Sharcnet equivalent of root_drive
# model loaded
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 8, 64, 64, 1)]    0
#
#  conv3d (Conv3D)             (None, 8, 64, 64, 16)     736
#
#  max_pooling3d (MaxPooling3D  (None, 8, 32, 32, 16)    0
#  )
#
#  conv3d_1 (Conv3D)           (None, 8, 32, 32, 8)      5768
#
#  max_pooling3d_1 (MaxPooling  (None, 4, 16, 16, 8)     0
#  3D)
#
#  dropout (Dropout)           (None, 4, 16, 16, 8)      0
#
#  conv3d_2 (Conv3D)           (None, 4, 16, 16, 8)      2888
#
#  max_pooling3d_2 (MaxPooling  (None, 2, 8, 8, 8)       0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 2, 8, 8, 8)        2888
#
#  up_sampling3d (UpSampling3D  (None, 4, 16, 16, 8)     0
#  )
#
#  conv3d_4 (Conv3D)           (None, 4, 16, 16, 8)      2888
#
#  up_sampling3d_1 (UpSampling  (None, 8, 32, 32, 8)     0
#  3D)
#
#  conv3d_5 (Conv3D)           (None, 8, 32, 32, 16)     5776
#
#  up_sampling3d_2 (UpSampling  (None, 8, 64, 64, 16)    0
#  3D)
#
#  conv3d_6 (Conv3D)           (None, 8, 64, 64, 1)      721
#
# =================================================================
# Total params: 21,665
# Trainable params: 21,665
# Non-trainable params: 0
# _________________________________________________________________
# None
# test np data
# npData not found, initializing..
# windowing vid at adl-01-cam0-d
# windowed vid shape (143, 8, 64, 64, 1)
# windowing vid at adl-02-cam0-d
# windowed vid shape (173, 8, 64, 64, 1)
# windowing vid at adl-03-cam0-d
# windowed vid shape (173, 8, 64, 64, 1)
# windowing vid at adl-04-cam0-d
# windowed vid shape (143, 8, 64, 64, 1)
# windowing vid at adl-05-cam0-d
# windowed vid shape (173, 8, 64, 64, 1)
# windowing vid at adl-06-cam0-d
# windowed vid shape (223, 8, 64, 64, 1)
# windowing vid at adl-07-cam0-d
# windowed vid shape (173, 8, 64, 64, 1)
# windowing vid at adl-08-cam0-d
# windowed vid shape (173, 8, 64, 64, 1)
# windowing vid at adl-09-cam0-d
# windowed vid shape (143, 8, 64, 64, 1)
# windowing vid at adl-10-cam0-d
# windowed vid shape (293, 8, 64, 64, 1)
# windowing vid at adl-11-cam0-d
# windowed vid shape (293, 8, 64, 64, 1)
# windowing vid at adl-12-cam0-d
# windowed vid shape (243, 8, 64, 64, 1)
# windowing vid at adl-13-cam0-d
# windowed vid shape (258, 8, 64, 64, 1)
# windowing vid at adl-14-cam0-d
# windowed vid shape (228, 8, 64, 64, 1)
# windowing vid at adl-15-cam0-d
# windowed vid shape (268, 8, 64, 64, 1)
# windowing vid at adl-16-cam0-d
# windowed vid shape (233, 8, 64, 64, 1)
# windowing vid at adl-17-cam0-d
# windowed vid shape (223, 8, 64, 64, 1)
# windowing vid at adl-18-cam0-d
# windowed vid shape (258, 8, 64, 64, 1)
# windowing vid at adl-19-cam0-d
# windowed vid shape (243, 8, 64, 64, 1)
# windowing vid at adl-20-cam0-d
# windowed vid shape (263, 8, 64, 64, 1)
# windowing vid at adl-21-cam0-d
# windowed vid shape (273, 8, 64, 64, 1)
# windowing vid at adl-22-cam0-d
# windowed vid shape (233, 8, 64, 64, 1)
# windowing vid at adl-23-cam0-d
# windowed vid shape (213, 8, 64, 64, 1)
# windowing vid at adl-24-cam0-d
# windowed vid shape (63, 8, 64, 64, 1)
# windowing vid at adl-25-cam0-d
# windowed vid shape (103, 8, 64, 64, 1)
# windowing vid at adl-26-cam0-d
# windowed vid shape (88, 8, 64, 64, 1)
# windowing vid at adl-27-cam0-d
# windowed vid shape (93, 8, 64, 64, 1)
# windowing vid at adl-28-cam0-d
# windowed vid shape (78, 8, 64, 64, 1)
# windowing vid at adl-29-cam0-d
# windowed vid shape (118, 8, 64, 64, 1)
# windowing vid at adl-30-cam0-d
# windowed vid shape (393, 8, 64, 64, 1)
# windowing vid at adl-31-cam0-d
# windowed vid shape (243, 8, 64, 64, 1)
# windowing vid at adl-32-cam0-d
# windowed vid shape (193, 8, 64, 64, 1)
# windowing vid at adl-33-cam0-d
# windowed vid shape (193, 8, 64, 64, 1)
# windowing vid at adl-34-cam0-d
# windowed vid shape (163, 8, 64, 64, 1)
# saving data to  ./npData/UR-Filled/ADL_data-proc-win_8.npy
# total windowed array shape (6767, 8, 64, 64, 1)
# (6767, 8, 64, 64, 1)
# data loaded
# ./Checkpoints/DSTCAE_C3D-.{epoch:03d}-{loss:.3f}.hdf5
# Epoch 1/50
#  99/212 [=============>................] - ETA: 8:27 - loss: 0.0426
# Epoch 1: saving model to ./Checkpoints/UR-Filled\DSTCAE_C3D-001-0.043.hdf5
# 199/212 [===========================>..] - ETA: 57s - loss: 0.0425
# Epoch 1: saving model to ./Checkpoints/UR-Filled\DSTCAE_C3D-001-0.042.hdf5
# 212/212 [==============================] - 929s 4s/step - loss: 0.0424
# Epoch 2/50
#  11/212 [>.............................] - ETA: 14:00 - loss: 0.0424
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7784\4054360827.py in <module>
#      23         print(exp_3D.train_data.shape)
#      24         print('data loaded')
# ---> 25         exp_3D.train()
#
# ~\OneDrive\Documents\Final Year Project\ElderMax\Fall-Detection\seq_exp.py in train(self, sample_weight)
#     100
#     101                 self.model.fit(self.train_data, self.train_data, epochs = self.epochs, batch_size = self.batch_size,\
# --> 102                  verbose = 1, callbacks = callbacks_list, sample_weight = sample_weight)
#     103                 self.save_exp()
#     104
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

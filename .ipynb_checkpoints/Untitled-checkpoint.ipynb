# %%
from models import *
from seq_exp import SeqExp


if __name__ == "__main__":
        '''
        These are the training setting. 
        '''
        dset = 'UR-Filled'
        img_width, img_height, win_len, epochs = 64,64, 8,50 #win len is set to 8 for paper
        stride = 1
       
        model, model_name, model_type = DSTCAE_C3D(img_width, img_height, win_len)
        

        print('model loaded')
        print(model.summary())

        exp_3D = SeqExp(model = model, model_name = model_name, epochs = epochs, \
                win_len = win_len, dset = dset, img_width = img_width, img_height = img_height)
        exp_3D.set_train_data()

        print(exp_3D.train_data.shape)
        print('data loaded')
        exp_3D.train()
# Out:
# Using Sharcnet equivalent of root_drive
# model loaded
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2, 64, 64, 1)]    0
#
#  conv3d (Conv3D)             (None, 2, 64, 64, 16)     736
#
#  max_pooling3d (MaxPooling3D  (None, 2, 32, 32, 16)    0
#  )
#
#  conv3d_1 (Conv3D)           (None, 2, 32, 32, 8)      5768
#
#  max_pooling3d_1 (MaxPooling  (None, 1, 16, 16, 8)     0
#  3D)
#
#  dropout (Dropout)           (None, 1, 16, 16, 8)      0
#
#  conv3d_2 (Conv3D)           (None, 1, 16, 16, 8)      2888
#
#  max_pooling3d_2 (MaxPooling  (None, 1, 8, 8, 8)       0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 1, 8, 8, 8)        2888
#
#  up_sampling3d (UpSampling3D  (None, 2, 16, 16, 8)     0
#  )
#
#  conv3d_4 (Conv3D)           (None, 2, 16, 16, 8)      2888
#
#  up_sampling3d_1 (UpSampling  (None, 4, 32, 32, 8)     0
#  3D)
#
#  dropout_1 (Dropout)         (None, 4, 32, 32, 8)      0
#
#  conv3d_5 (Conv3D)           (None, 4, 32, 32, 16)     5776
#
#  up_sampling3d_2 (UpSampling  (None, 4, 64, 64, 16)    0
#  3D)
#
#  conv3d_6 (Conv3D)           (None, 4, 64, 64, 1)      721
#
# =================================================================
# Total params: 21,665
# Trainable params: 21,665
# Non-trainable params: 0
# _________________________________________________________________
# None
# test np data
# npData not found, initializing..
# windowing vid at adl-01-cam0-d
# windowed vid shape (149, 2, 64, 64, 1)
# windowing vid at adl-02-cam0-d
# windowed vid shape (179, 2, 64, 64, 1)
# windowing vid at adl-03-cam0-d
# windowed vid shape (179, 2, 64, 64, 1)
# windowing vid at adl-04-cam0-d
# windowed vid shape (149, 2, 64, 64, 1)
# windowing vid at adl-05-cam0-d
# windowed vid shape (179, 2, 64, 64, 1)
# windowing vid at adl-06-cam0-d
# windowed vid shape (229, 2, 64, 64, 1)
# windowing vid at adl-07-cam0-d
# windowed vid shape (179, 2, 64, 64, 1)
# windowing vid at adl-08-cam0-d
# windowed vid shape (179, 2, 64, 64, 1)
# windowing vid at adl-09-cam0-d
# windowed vid shape (149, 2, 64, 64, 1)
# windowing vid at adl-10-cam0-d
# windowed vid shape (299, 2, 64, 64, 1)
# windowing vid at adl-11-cam0-d
# windowed vid shape (299, 2, 64, 64, 1)
# windowing vid at adl-12-cam0-d
# windowed vid shape (249, 2, 64, 64, 1)
# windowing vid at adl-13-cam0-d
# windowed vid shape (264, 2, 64, 64, 1)
# windowing vid at adl-14-cam0-d
# windowed vid shape (234, 2, 64, 64, 1)
# windowing vid at adl-15-cam0-d
# windowed vid shape (274, 2, 64, 64, 1)
# windowing vid at adl-16-cam0-d
# windowed vid shape (239, 2, 64, 64, 1)
# windowing vid at adl-17-cam0-d
# windowed vid shape (229, 2, 64, 64, 1)
# windowing vid at adl-18-cam0-d
# windowed vid shape (264, 2, 64, 64, 1)
# windowing vid at adl-19-cam0-d
# windowed vid shape (249, 2, 64, 64, 1)
# windowing vid at adl-20-cam0-d
# windowed vid shape (269, 2, 64, 64, 1)
# windowing vid at adl-21-cam0-d
# windowed vid shape (279, 2, 64, 64, 1)
# windowing vid at adl-22-cam0-d
# windowed vid shape (239, 2, 64, 64, 1)
# windowing vid at adl-23-cam0-d
# windowed vid shape (219, 2, 64, 64, 1)
# windowing vid at adl-24-cam0-d
# windowed vid shape (69, 2, 64, 64, 1)
# windowing vid at adl-25-cam0-d
# windowed vid shape (109, 2, 64, 64, 1)
# windowing vid at adl-26-cam0-d
# windowed vid shape (94, 2, 64, 64, 1)
# windowing vid at adl-27-cam0-d
# windowed vid shape (99, 2, 64, 64, 1)
# windowing vid at adl-28-cam0-d
# windowed vid shape (84, 2, 64, 64, 1)
# windowing vid at adl-29-cam0-d
# windowed vid shape (124, 2, 64, 64, 1)
# windowing vid at adl-30-cam0-d
# windowed vid shape (399, 2, 64, 64, 1)
# windowing vid at adl-31-cam0-d
# windowed vid shape (249, 2, 64, 64, 1)
# windowing vid at adl-32-cam0-d
# windowed vid shape (199, 2, 64, 64, 1)
# windowing vid at adl-33-cam0-d
# windowed vid shape (199, 2, 64, 64, 1)
# windowing vid at adl-34-cam0-d
# windowed vid shape (169, 2, 64, 64, 1)
# saving data to  ./npData/UR-Filled/ADL_data-proc-win_2.npy
# total windowed array shape (6971, 2, 64, 64, 1)
# (6971, 2, 64, 64, 1)
# data loaded
# ./Checkpoints/DSTCAE_C3D-.{epoch:03d}-{loss:.3f}.hdf5
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27884\67988318.py in <module>
#      23         print(exp_3D.train_data.shape)
#      24         print('data loaded')
# ---> 25         exp_3D.train()
#
# ~\OneDrive\Documents\Final Year Project\ElderMax\Fall-Detection\seq_exp.py in train(self, sample_weight)
#     100
#     101                 self.model.fit(self.train_data, self.train_data, epochs = self.epochs, batch_size = self.batch_size,\
# --> 102                  verbose = 2, callbacks = callbacks_list, sample_weight = sample_weight)
#     103                 self.save_exp()
#     104
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\func_graph.py in autograph_handler(*args, **kwargs)
#    1145           except Exception as e:  # pylint:disable=broad-except
#    1146             if hasattr(e, "ag_error_metadata"):
# -> 1147               raise e.ag_error_metadata.to_exception(e)
#    1148             else:
#    1149               raise
#
# ValueError: in user code:
#
#     File "C:\Users\rashm\anaconda3\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\rashm\anaconda3\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\rashm\anaconda3\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\rashm\anaconda3\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\rashm\anaconda3\envs\tf-gpu\lib\site-packages\keras\engine\training.py", line 919, in compute_loss
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     File "C:\Users\rashm\anaconda3\envs\tf-gpu\lib\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\rashm\anaconda3\envs\tf-gpu\lib\site-packages\keras\losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\rashm\anaconda3\envs\tf-gpu\lib\site-packages\keras\losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\rashm\anaconda3\envs\tf-gpu\lib\site-packages\keras\losses.py", line 1329, in mean_squared_error
#         return backend.mean(tf.math.squared_difference(y_pred, y_true), axis=-1)
#
#     ValueError: Dimensions must be equal, but are 4 and 2 for '{{node mean_squared_error/SquaredDifference}} = SquaredDifference[T=DT_FLOAT](model/conv3d_6/Tanh, IteratorGetNext:1)' with input shapes: [?,4,64,64,1], [?,2,64,64,1].
